# %% [markdown]
# #  Test notebook for overflowing content

# %% [markdown]
# markdown image:
#
# <img src="https://placehold.co/800x200.png">
#
# unconfined markdown image:
#
# <img src="https://placehold.co/800x200.png" class="unconfined">

# %%
from IPython.display import Image, IFrame

# %% [markdown]
# Overflow image in HTML (non-embedded)

# %%
Image(url="https://placehold.co/800x200.png", embed=False)
# Out:
# <img src="http://place-hold.it/800x200.png"   />

# %% [markdown]
# Overflow image:

# %%
Image(url="https://placehold.co/800x200.png", embed=True)

# %% [markdown]
# Overflow, unconfined

# %%
Image(url="https://placehold.co/800x200.png", embed=True, unconfined=True)

# %% [markdown]
# Overflow with explicit height, width (retina):

# %%
Image(url="https://placehold.co/1800x200.jpg", embed=True, retina=True)

# %% [markdown]
# Overflowing IFrame:

# %%
IFrame(src="http://ipython.org", width=900, height=400)
# Out:
#         <iframe
#             width="900"
#             height="400"
#             src="http://ipython.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Overflowing table:

# %%
import pandas as pd
pd.DataFrame([['column'] * 15])
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  column  column  column  column  column  column  column  column  column
#
#        9       10      11      12      13      14
# 0  column  column  column  column  column  column
